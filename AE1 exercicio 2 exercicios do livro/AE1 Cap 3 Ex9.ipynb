# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import time

# %%
class neuralNetwork:
    def __init__(
            self, layers, activation, activationGradient, xavierInitialization=True
    ):
        self.L = len(layers)  # number of layers
        if xavierInitialization == True:
            self.weights = [
                torch.nn.init.xavier_uniform_(
                    torch.zeros((layers[i], layers[i + 1])),
                    gain=torch.nn.init.calculate_gain("sigmoid"),
                ).numpy()
                for i in range(self.L - 1)
            ]
        else:
            self.weights = [
                np.random.rand(layers[i], layers[i + 1]) for i in range(self.L - 1)
            ]
        self.biases = [np.random.rand(1, layers[i + 1]) for i in range(self.L - 1)]

        self.layerActivations = []

        self.weightGradients = [
            np.zeros((layers[i], layers[i + 1])) for i in range(self.L - 1)
        ]
        self.biasGradients = [np.zeros((1, layers[i + 1])) for i in range(self.L - 1)]

 # helper variables to store gradients per sample
        self.currentWeightGradients = [
            np.zeros((layers[i], layers[i + 1])) for i in range(self.L - 1)
        ]
        self.currentBiasGradients = [
            np.zeros((1, layers[i + 1])) for i in range(self.L - 1)
        ]

        self.activation = activation
        self.activationGradient = activationGradient

    def forward(self, x):
        self.layerActivations = []  # clear activations
        a = x
        self.layerActivations.append(a)  # activation is not applied to input
        for i in range(self.L - 1):
            z = a @ self.weights[i] + self.biases[i]
            self.layerActivations.append(z)  # store activations
            a = self.activation(z)
        return a

    def backward(self, y):
        if len(self.layerActivations) > 0:  # check if forward pass has been performed
            numberOfSamples = len(self.layerActivations[0])

# for a single sample
            if numberOfSamples == 1:
                deltaL = -(
                        y - self.activation(self.layerActivations[self.L - 1])
                ) * self.activationGradient(self.layerActivations[self.L - 1])
                self.biasGradients[self.L - 2] = deltaL
                for i in range(
                        self.L - 2
                ):  # indices of layer activation shifted due to stored input
                    deltal = np.sum(
                        self.weights[self.L - 2 - i]
                        * self.biasGradients[self.L - 2 - i],
                        1,
                    ) * self.activationGradient(self.layerActivations[self.L - 2 - i])
                    self.biasGradients[self.L - 3 - i] = deltal

                self.weightGradients[0] = (
                        np.transpose(self.layerActivations[0]) @ self.biasGradients[0]
                )  # without activation for input
                for i in range(1, self.L - 1):
                    self.weightGradients[i] = (
                            np.transpose(self.activation(self.layerActivations[i]))
                            @ self.biasGradients[i]
                    )

# for multiple samples using for loop over samples
            elif numberOfSamples > 1:
                for j in range(numberOfSamples):

                    deltaL = -(
                            y[j: j + 1]
                            - self.activation(self.layerActivations[self.L - 1][j: j + 1])
                    ) * self.activationGradient(
                        self.layerActivations[self.L - 1][j: j + 1]
                    )
                    self.currentBiasGradients[self.L - 2] = (
                            deltaL / numberOfSamples
                    )  # division by number of samples, as we are taking the mean
                    self.biasGradients[self.L - 2] += self.currentBiasGradients[
                        self.L - 2
                        ]
                    for i in range(
                            self.L - 2
                    ):  # indices of layer activation shifted due to stored input
                        deltal = np.sum(
                            self.weights[self.L - 2 - i]
                            * self.currentBiasGradients[self.L - 2 - i],
                            1,
                        ) * self.activationGradient(
                            self.layerActivations[self.L - 2 - i][j: j + 1]
                        )
                        self.currentBiasGradients[self.L - 3 - i] = deltal
                        self.biasGradients[self.L - 3 - i] += self.currentBiasGradients[
                            self.L - 3 - i
                            ]

                    # without activation for input
                    self.currentWeightGradients[0] = (
                            np.transpose(self.layerActivations[0][j: j + 1])
                            @ self.currentBiasGradients[0]
                    )
                    self.weightGradients[0] += self.currentWeightGradients[0]
                    for i in range(1, self.L - 1):
                        self.currentWeightGradients[i] = (
                                np.transpose(
                                    self.activation(self.layerActivations[i][j: j + 1])
                                )
                                @ self.currentBiasGradients[i]
                        )
                        self.weightGradients[i] += self.currentWeightGradients[i]

        else:
            print("backward propagation not possible")

    def zero_grad(self):
        self.weightGradients = [
            np.zeros((layers[i], layers[i + 1])) for i in range(self.L - 1)
        ]
        self.biasGradients = [np.zeros((1, layers[i + 1])) for i in range(self.L - 1)]

    def step(self, lr):
        for i in range(self.L - 1):
            self.weights[i] -= lr * self.weightGradients[i]
            self.biases[i] -= lr * self.biasGradients[i]

# %%
layers = [1, 4, 4, 1]
sigmoid = lambda x: 1 / (1 + np.exp(-x))
sigmoidGradient = lambda x: sigmoid(x) * (1 - sigmoid(x))

model = neuralNetwork(layers, sigmoid, sigmoidGradient)

# input data
x = np.expand_dims(np.linspace(0, 1, 2), 1) + 0.2
y = np.sin(4 * np.pi * x) ** 2

# %%
# prediction
yPred = model.forward(x)

# cost
C = 0.5 * np.mean((yPred - y) ** 2)

# gradient
model.backward(y)

# %%
class neuralNetworkTorch(torch.nn.Module):
    def __init__(self, layers, activationFunction=torch.nn.Sigmoid()):
        super().__init__()
        modules = []
        for i in range(len(layers) - 1):
            modules.append(torch.nn.Linear(layers[i], layers[i + 1]))
            modules.append(activationFunction)

        self.model = torch.nn.Sequential(*modules)

    def forward(self, x):
        return self.model(x)


modelTorch = neuralNetworkTorch(layers)

# copy parameters
with torch.no_grad():
    for i, param in enumerate(modelTorch.parameters()):
        if i % 2 == 0:
            param.data = torch.from_numpy(model.weights[i // 2]).to(torch.float64).t()
        else:
            param.data = torch.from_numpy(model.biases[i // 2]).to(torch.float64)

# %%
xTorch = torch.from_numpy(x).to(torch.float64)
yPredTorch = modelTorch.forward(xTorch)

CTorch = 0.5 * torch.mean((yPredTorch - torch.from_numpy(y).to(torch.float64)) ** 2)
CTorch.backward()

# %%
layer = 0
# weight gradients
print("weight:")
print(np.transpose(model.weightGradients[layer]))
print(list(modelTorch.parameters())[2 * layer].grad)

# bias gradients
print("bias:")
print(model.biasGradients[layer])
print(list(modelTorch.parameters())[2 * layer + 1].grad)
# Out:
# weight:
# [[-0.00247003]
#  [ 0.00057588]
#  [ 0.00159489]
#  [ 0.00079239]]
# tensor([[-0.0025],
#         [ 0.0006],
#         [ 0.0016],
#         [ 0.0008]], dtype=torch.float64)
# bias:
# [[-0.00402666  0.00102783  0.00232467  0.00124863]]
# tensor([[-0.0040,  0.0010,  0.0023,  0.0012]], dtype=torch.float64)

# %%
class AdamOptimizer:
    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999, epsilon=1e-8):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.epsilon = epsilon
        self.m = None
        self.n = None
        self.t = 0

    def updateParams(self, params, grads):
        if self.m is None:
            self.m = [np.zeros_like(param) for param in params]
        if self.n is None:
            self.n = [np.zeros_like(param) for param in params]

        self.t += 1  # exponent increases with epochs
        updatedParams = []

        for p, g, m, n in zip(params, grads, self.m, self.n):
            m[:] = self.beta1 * m + (1 - self.beta1) * g
            n[:] = self.beta2 * n + (1 - self.beta2) * (g ** 2)

            mhat = m / (1 - self.beta1 ** self.t)
            nhat = n / (1 - self.beta2 ** self.t)

            updatedParams.append(p - self.lr * mhat / (np.sqrt(nhat) + self.epsilon))

        return updatedParams

# %%
selectOptimizer = "gradientDescent"
# selectOptimizer = 'Adam'

# %%
layers = [1, 20, 20, 1]
sigmoid = lambda x: 1 / (1 + np.exp(-x))
sigmoidGradient = lambda x: sigmoid(x) * (1 - sigmoid(x))

model = neuralNetwork(layers, sigmoid, sigmoidGradient)

x = np.expand_dims(np.linspace(0, 1, 40), 1)  # training grid

if selectOptimizer == "gradientDescent":
    y = x ** 2
    epochs = 10000
    lr = 1e-1
elif selectOptimizer == "Adam":
    y = np.sin(2 * np.pi * x) ** 2  # a more difficult function
    lr = 1e-2
    optimizer = AdamOptimizer(lr=lr)

# %%
start = time.perf_counter()
for epoch in range(epochs):

    model.zero_grad()
    yPred = model.forward(x)
    C = 0.5 * np.mean((yPred - y) ** 2)
    model.backward(y)

    if selectOptimizer == "gradientDescent":
        model.step(lr)
    elif selectOptimizer == "Adam":
        updatedParameters = optimizer.updateParams(
            model.weights + model.biases, model.weightGradients + model.biasGradients
        )
        model.weights = updatedParameters[: model.L - 1]
        model.biases = updatedParameters[model.L - 1:]

    if epoch % 100 == 0:
        elapsedTime = time.perf_counter() - start
        string = "Epoch: {}/{}\t\tCost = {:.2e}\t\tElapsed time = {:2f}"
        print(string.format(epoch, epochs, C, elapsedTime))
        start = time.perf_counter()
# Out:
# Epoch: 0/10000		Cost = 9.35e-02		Elapsed time = 0.033228
# Epoch: 100/10000		Cost = 4.65e-02		Elapsed time = 2.214158
# Epoch: 200/10000		Cost = 4.64e-02		Elapsed time = 2.524167
# Epoch: 300/10000		Cost = 4.63e-02		Elapsed time = 3.999963
# Epoch: 400/10000		Cost = 4.62e-02		Elapsed time = 2.190383
# Epoch: 500/10000		Cost = 4.61e-02		Elapsed time = 2.797219
# Epoch: 600/10000		Cost = 4.60e-02		Elapsed time = 2.010445
# Epoch: 700/10000		Cost = 4.59e-02		Elapsed time = 1.895191
# Epoch: 800/10000		Cost = 4.57e-02		Elapsed time = 1.792784
# Epoch: 900/10000		Cost = 4.56e-02		Elapsed time = 2.686463
# Epoch: 1000/10000		Cost = 4.55e-02		Elapsed time = 1.911796
# Epoch: 1100/10000		Cost = 4.54e-02		Elapsed time = 2.208262
# Epoch: 1200/10000		Cost = 4.53e-02		Elapsed time = 1.981855
# Epoch: 1300/10000		Cost = 4.51e-02		Elapsed time = 1.706005
# Epoch: 1400/10000		Cost = 4.50e-02		Elapsed time = 1.996235
# Epoch: 1500/10000		Cost = 4.48e-02		Elapsed time = 1.796412
# Epoch: 1600/10000		Cost = 4.47e-02		Elapsed time = 1.617814
# Epoch: 1700/10000		Cost = 4.45e-02		Elapsed time = 2.687753
# Epoch: 1800/10000		Cost = 4.44e-02		Elapsed time = 2.416026
# Epoch: 1900/10000		Cost = 4.42e-02		Elapsed time = 2.198432
# Epoch: 2000/10000		Cost = 4.40e-02		Elapsed time = 2.378765
# Epoch: 2100/10000		Cost = 4.38e-02		Elapsed time = 2.123732
# Epoch: 2200/10000		Cost = 4.36e-02		Elapsed time = 2.679347
# Epoch: 2300/10000		Cost = 4.34e-02		Elapsed time = 3.615857
# Epoch: 2400/10000		Cost = 4.31e-02		Elapsed time = 2.686715
# Epoch: 2500/10000		Cost = 4.29e-02		Elapsed time = 2.106509
# Epoch: 2600/10000		Cost = 4.26e-02		Elapsed time = 1.695305
# Epoch: 2700/10000		Cost = 4.23e-02		Elapsed time = 1.701464
# Epoch: 2800/10000		Cost = 4.20e-02		Elapsed time = 2.103486
# Epoch: 2900/10000		Cost = 4.17e-02		Elapsed time = 1.894686
# Epoch: 3000/10000		Cost = 4.14e-02		Elapsed time = 1.912030
# Epoch: 3100/10000		Cost = 4.10e-02		Elapsed time = 1.796383
# Epoch: 3200/10000		Cost = 4.06e-02		Elapsed time = 2.188538
# Epoch: 3300/10000		Cost = 4.02e-02		Elapsed time = 3.802859
# Epoch: 3400/10000		Cost = 3.98e-02		Elapsed time = 5.802539
# Epoch: 3500/10000		Cost = 3.93e-02		Elapsed time = 2.190981
# Epoch: 3600/10000		Cost = 3.88e-02		Elapsed time = 2.199877
# Epoch: 3700/10000		Cost = 3.83e-02		Elapsed time = 2.020703
# Epoch: 3800/10000		Cost = 3.77e-02		Elapsed time = 1.995122
# Epoch: 3900/10000		Cost = 3.71e-02		Elapsed time = 2.584106
# Epoch: 4000/10000		Cost = 3.65e-02		Elapsed time = 2.409721
# Epoch: 4100/10000		Cost = 3.58e-02		Elapsed time = 4.238155
# Epoch: 4200/10000		Cost = 3.51e-02		Elapsed time = 3.350684
# Epoch: 4300/10000		Cost = 3.43e-02		Elapsed time = 2.300308
# Epoch: 4400/10000		Cost = 3.35e-02		Elapsed time = 2.098369
# Epoch: 4500/10000		Cost = 3.27e-02		Elapsed time = 2.206308
# Epoch: 4600/10000		Cost = 3.18e-02		Elapsed time = 2.895242
# Epoch: 4700/10000		Cost = 3.08e-02		Elapsed time = 2.010304
# Epoch: 4800/10000		Cost = 2.99e-02		Elapsed time = 1.993078
# Epoch: 4900/10000		Cost = 2.88e-02		Elapsed time = 2.112042
# Epoch: 5000/10000		Cost = 2.78e-02		Elapsed time = 1.983754
# Epoch: 5100/10000		Cost = 2.67e-02		Elapsed time = 2.212506
# Epoch: 5200/10000		Cost = 2.56e-02		Elapsed time = 1.794277
# Epoch: 5300/10000		Cost = 2.44e-02		Elapsed time = 1.601470
# Epoch: 5400/10000		Cost = 2.33e-02		Elapsed time = 2.009030
# Epoch: 5500/10000		Cost = 2.21e-02		Elapsed time = 2.086554
# Epoch: 5600/10000		Cost = 2.09e-02		Elapsed time = 2.612740
# Epoch: 5700/10000		Cost = 1.97e-02		Elapsed time = 1.887390
# Epoch: 5800/10000		Cost = 1.86e-02		Elapsed time = 1.914477
# Epoch: 5900/10000		Cost = 1.74e-02		Elapsed time = 2.185625
# Epoch: 6000/10000		Cost = 1.63e-02		Elapsed time = 2.000092
# Epoch: 6100/10000		Cost = 1.53e-02		Elapsed time = 2.817110
# Epoch: 6200/10000		Cost = 1.43e-02		Elapsed time = 1.789307
# Epoch: 6300/10000		Cost = 1.33e-02		Elapsed time = 1.890228
# Epoch: 6400/10000		Cost = 1.23e-02		Elapsed time = 1.701102
# Epoch: 6500/10000		Cost = 1.15e-02		Elapsed time = 1.904417
# Epoch: 6600/10000		Cost = 1.06e-02		Elapsed time = 2.293677
# Epoch: 6700/10000		Cost = 9.87e-03		Elapsed time = 1.717080
# Epoch: 6800/10000		Cost = 9.15e-03		Elapsed time = 2.584536
# Epoch: 6900/10000		Cost = 8.49e-03		Elapsed time = 1.816087
# Epoch: 7000/10000		Cost = 7.87e-03		Elapsed time = 1.788074
# Epoch: 7100/10000		Cost = 7.30e-03		Elapsed time = 2.011280
# Epoch: 7200/10000		Cost = 6.77e-03		Elapsed time = 2.190006
# Epoch: 7300/10000		Cost = 6.29e-03		Elapsed time = 1.614244
# Epoch: 7400/10000		Cost = 5.85e-03		Elapsed time = 1.777387
# Epoch: 7500/10000		Cost = 5.44e-03		Elapsed time = 1.613554
# Epoch: 7600/10000		Cost = 5.06e-03		Elapsed time = 1.683793
# Epoch: 7700/10000		Cost = 4.72e-03		Elapsed time = 1.905640
# Epoch: 7800/10000		Cost = 4.41e-03		Elapsed time = 2.908155
# Epoch: 7900/10000		Cost = 4.12e-03		Elapsed time = 2.093360
# Epoch: 8000/10000		Cost = 3.85e-03		Elapsed time = 2.209012
# Epoch: 8100/10000		Cost = 3.61e-03		Elapsed time = 3.110718
# Epoch: 8200/10000		Cost = 3.39e-03		Elapsed time = 2.080861
# Epoch: 8300/10000		Cost = 3.18e-03		Elapsed time = 1.792025
# Epoch: 8400/10000		Cost = 3.00e-03		Elapsed time = 1.605111
# Epoch: 8500/10000		Cost = 2.83e-03		Elapsed time = 1.797073
# Epoch: 8600/10000		Cost = 2.67e-03		Elapsed time = 1.915024
# Epoch: 8700/10000		Cost = 2.52e-03		Elapsed time = 1.698034
# Epoch: 8800/10000		Cost = 2.39e-03		Elapsed time = 1.703595
# Epoch: 8900/10000		Cost = 2.27e-03		Elapsed time = 1.987721
# Epoch: 9000/10000		Cost = 2.15e-03		Elapsed time = 3.992106
# Epoch: 9100/10000		Cost = 2.05e-03		Elapsed time = 5.100391
# Epoch: 9200/10000		Cost = 1.95e-03		Elapsed time = 1.824354
# Epoch: 9300/10000		Cost = 1.87e-03		Elapsed time = 1.881949
# Epoch: 9400/10000		Cost = 1.78e-03		Elapsed time = 1.892797
# Epoch: 9500/10000		Cost = 1.71e-03		Elapsed time = 2.108654
# Epoch: 9600/10000		Cost = 1.64e-03		Elapsed time = 2.007453
# Epoch: 9700/10000		Cost = 1.57e-03		Elapsed time = 2.193684
# Epoch: 9800/10000		Cost = 1.51e-03		Elapsed time = 2.308504
# Epoch: 9900/10000		Cost = 1.46e-03		Elapsed time = 2.206153

# %%
yPred = model.forward(x)

fig, ax = plt.subplots(figsize=(12, 6))
ax.grid()
ax.plot(x, y, "k", label="ground truth")
ax.plot(x, yPred, "r--", label="prediction")
ax.legend()
plt.show()

# %%
modelTorch = neuralNetworkTorch(layers)
xTorch = torch.from_numpy(x).to(torch.float32)
yTorch = torch.from_numpy(y).to(torch.float32)
if selectOptimizer == "gradientDescent":
    optimizer = torch.optim.SGD(modelTorch.parameters(), lr)
elif selectOptimizer == "Adam":
    optimizer = torch.optim.Adam(modelTorch.parameters(), lr)

# %%
start = time.perf_counter()
for epoch in range(epochs):
    optimizer.zero_grad()
    yPredTorch = modelTorch.forward(xTorch)
    CTorch = 0.5 * torch.mean((yPredTorch - yTorch) ** 2)
    CTorch.backward()

    optimizer.step()

    if epoch % 100 == 0:
        elapsedTime = time.perf_counter() - start
        string = "Epoch: {}/{}\t\tCost = {:.2e}\t\tElapsed time = {:2f}"
        print(string.format(epoch, epochs, CTorch.detach(), elapsedTime))
        start = time.perf_counter()
# Out:
# Epoch: 0/10000		Cost = 5.28e-02		Elapsed time = 0.003274
# Epoch: 100/10000		Cost = 4.70e-02		Elapsed time = 0.408215
# Epoch: 200/10000		Cost = 4.69e-02		Elapsed time = 0.498479
# Epoch: 300/10000		Cost = 4.68e-02		Elapsed time = 0.590048
# Epoch: 400/10000		Cost = 4.68e-02		Elapsed time = 0.502405
# Epoch: 500/10000		Cost = 4.67e-02		Elapsed time = 0.723616
# Epoch: 600/10000		Cost = 4.67e-02		Elapsed time = 0.490049
# Epoch: 700/10000		Cost = 4.66e-02		Elapsed time = 0.616571
# Epoch: 800/10000		Cost = 4.65e-02		Elapsed time = 0.563112
# Epoch: 900/10000		Cost = 4.65e-02		Elapsed time = 0.603209
# Epoch: 1000/10000		Cost = 4.64e-02		Elapsed time = 0.499466
# Epoch: 1100/10000		Cost = 4.64e-02		Elapsed time = 0.600636
# Epoch: 1200/10000		Cost = 4.63e-02		Elapsed time = 0.399349
# Epoch: 1300/10000		Cost = 4.62e-02		Elapsed time = 0.393096
# Epoch: 1400/10000		Cost = 4.61e-02		Elapsed time = 0.306895
# Epoch: 1500/10000		Cost = 4.61e-02		Elapsed time = 0.311390
# Epoch: 1600/10000		Cost = 4.60e-02		Elapsed time = 0.385491
# Epoch: 1700/10000		Cost = 4.59e-02		Elapsed time = 0.408733
# Epoch: 1800/10000		Cost = 4.58e-02		Elapsed time = 0.587105
# Epoch: 1900/10000		Cost = 4.58e-02		Elapsed time = 0.414915
# Epoch: 2000/10000		Cost = 4.57e-02		Elapsed time = 0.384241
# Epoch: 2100/10000		Cost = 4.56e-02		Elapsed time = 0.304586
# Epoch: 2200/10000		Cost = 4.55e-02		Elapsed time = 0.301168
# Epoch: 2300/10000		Cost = 4.54e-02		Elapsed time = 0.300943
# Epoch: 2400/10000		Cost = 4.53e-02		Elapsed time = 0.302650
# Epoch: 2500/10000		Cost = 4.52e-02		Elapsed time = 0.302622
# Epoch: 2600/10000		Cost = 4.51e-02		Elapsed time = 0.385397
# Epoch: 2700/10000		Cost = 4.49e-02		Elapsed time = 0.303253
# Epoch: 2800/10000		Cost = 4.48e-02		Elapsed time = 0.316037
# Epoch: 2900/10000		Cost = 4.47e-02		Elapsed time = 0.389432
# Epoch: 3000/10000		Cost = 4.45e-02		Elapsed time = 0.306730
# Epoch: 3100/10000		Cost = 4.44e-02		Elapsed time = 0.307847
# Epoch: 3200/10000		Cost = 4.42e-02		Elapsed time = 0.386084
# Epoch: 3300/10000		Cost = 4.41e-02		Elapsed time = 0.299793
# Epoch: 3400/10000		Cost = 4.39e-02		Elapsed time = 0.306140
# Epoch: 3500/10000		Cost = 4.37e-02		Elapsed time = 0.384138
# Epoch: 3600/10000		Cost = 4.35e-02		Elapsed time = 0.400274
# Epoch: 3700/10000		Cost = 4.33e-02		Elapsed time = 0.308159
# Epoch: 3800/10000		Cost = 4.31e-02		Elapsed time = 0.301159
# Epoch: 3900/10000		Cost = 4.28e-02		Elapsed time = 0.302857
# Epoch: 4000/10000		Cost = 4.26e-02		Elapsed time = 0.306563
# Epoch: 4100/10000		Cost = 4.23e-02		Elapsed time = 0.303301
# Epoch: 4200/10000		Cost = 4.20e-02		Elapsed time = 0.383841
# Epoch: 4300/10000		Cost = 4.17e-02		Elapsed time = 0.306160
# Epoch: 4400/10000		Cost = 4.14e-02		Elapsed time = 0.385166
# Epoch: 4500/10000		Cost = 4.10e-02		Elapsed time = 0.310461
# Epoch: 4600/10000		Cost = 4.06e-02		Elapsed time = 0.304928
# Epoch: 4700/10000		Cost = 4.02e-02		Elapsed time = 0.302675
# Epoch: 4800/10000		Cost = 3.98e-02		Elapsed time = 0.383269
# Epoch: 4900/10000		Cost = 3.93e-02		Elapsed time = 0.306303
# Epoch: 5000/10000		Cost = 3.88e-02		Elapsed time = 0.307810
# Epoch: 5100/10000		Cost = 3.83e-02		Elapsed time = 0.303472
# Epoch: 5200/10000		Cost = 3.77e-02		Elapsed time = 0.304228
# Epoch: 5300/10000		Cost = 3.71e-02		Elapsed time = 0.300864
# Epoch: 5400/10000		Cost = 3.65e-02		Elapsed time = 0.304058
# Epoch: 5500/10000		Cost = 3.58e-02		Elapsed time = 0.301602
# Epoch: 5600/10000		Cost = 3.51e-02		Elapsed time = 0.304755
# Epoch: 5700/10000		Cost = 3.43e-02		Elapsed time = 0.305044
# Epoch: 5800/10000		Cost = 3.35e-02		Elapsed time = 0.300348
# Epoch: 5900/10000		Cost = 3.26e-02		Elapsed time = 0.299098
# Epoch: 6000/10000		Cost = 3.17e-02		Elapsed time = 0.387512
# Epoch: 6100/10000		Cost = 3.08e-02		Elapsed time = 0.306381
# Epoch: 6200/10000		Cost = 2.98e-02		Elapsed time = 0.299637
# Epoch: 6300/10000		Cost = 2.88e-02		Elapsed time = 0.397438
# Epoch: 6400/10000		Cost = 2.77e-02		Elapsed time = 0.316429
# Epoch: 6500/10000		Cost = 2.66e-02		Elapsed time = 0.387524
# Epoch: 6600/10000		Cost = 2.54e-02		Elapsed time = 0.312657
# Epoch: 6700/10000		Cost = 2.43e-02		Elapsed time = 0.379720
# Epoch: 6800/10000		Cost = 2.31e-02		Elapsed time = 0.301549
# Epoch: 6900/10000		Cost = 2.19e-02		Elapsed time = 0.307060
# Epoch: 7000/10000		Cost = 2.07e-02		Elapsed time = 0.297828
# Epoch: 7100/10000		Cost = 1.96e-02		Elapsed time = 0.306261
# Epoch: 7200/10000		Cost = 1.84e-02		Elapsed time = 0.304327
# Epoch: 7300/10000		Cost = 1.73e-02		Elapsed time = 0.380178
# Epoch: 7400/10000		Cost = 1.62e-02		Elapsed time = 0.216098
# Epoch: 7500/10000		Cost = 1.51e-02		Elapsed time = 0.297377
# Epoch: 7600/10000		Cost = 1.41e-02		Elapsed time = 0.300114
# Epoch: 7700/10000		Cost = 1.31e-02		Elapsed time = 0.294248
# Epoch: 7800/10000		Cost = 1.22e-02		Elapsed time = 0.295778
# Epoch: 7900/10000		Cost = 1.14e-02		Elapsed time = 0.214001
# Epoch: 8000/10000		Cost = 1.05e-02		Elapsed time = 0.295597
# Epoch: 8100/10000		Cost = 9.79e-03		Elapsed time = 0.295949
# Epoch: 8200/10000		Cost = 9.08e-03		Elapsed time = 0.295730
# Epoch: 8300/10000		Cost = 8.42e-03		Elapsed time = 0.296801
# Epoch: 8400/10000		Cost = 7.81e-03		Elapsed time = 0.215158
# Epoch: 8500/10000		Cost = 7.25e-03		Elapsed time = 0.297701
# Epoch: 8600/10000		Cost = 6.73e-03		Elapsed time = 0.297007
# Epoch: 8700/10000		Cost = 6.26e-03		Elapsed time = 0.303011
# Epoch: 8800/10000		Cost = 5.82e-03		Elapsed time = 0.303894
# Epoch: 8900/10000		Cost = 5.42e-03		Elapsed time = 0.494700
# Epoch: 9000/10000		Cost = 5.05e-03		Elapsed time = 0.389136
# Epoch: 9100/10000		Cost = 4.71e-03		Elapsed time = 0.301217
# Epoch: 9200/10000		Cost = 4.40e-03		Elapsed time = 0.303838
# Epoch: 9300/10000		Cost = 4.11e-03		Elapsed time = 0.297736
# Epoch: 9400/10000		Cost = 3.85e-03		Elapsed time = 0.306281
# Epoch: 9500/10000		Cost = 3.61e-03		Elapsed time = 0.299548
# Epoch: 9600/10000		Cost = 3.39e-03		Elapsed time = 0.388151
# Epoch: 9700/10000		Cost = 3.19e-03		Elapsed time = 0.216790
# Epoch: 9800/10000		Cost = 3.00e-03		Elapsed time = 0.388049
# Epoch: 9900/10000		Cost = 2.83e-03		Elapsed time = 0.294841

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.grid()
ax.plot(x, y, "k", label="ground truth")
ax.plot(xTorch, yPredTorch.detach(), "r--", label="torch prediction")
ax.plot(xTorch, yPred, "b--", label="scratch prediction")
ax.legend()
plt.show()
